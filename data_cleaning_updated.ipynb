# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("C:/Users/Admin/Downloads/ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2 = pd.read_csv("C:/Users/Admin/Downloads/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3 = pd.read_csv("C:/Users/Admin/Downloads/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df4 = pd.read_csv("C:/Users/Admin/Downloads/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df5 = pd.read_csv("C:/Users/Admin/Downloads/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
df4.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
df = pd.concat([df1,df2,df3,df4,df5],axis=0)

# %%
df.shape
# Out:
# (933541, 11)

# %%
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(312)

# %%
df = df.drop_duplicates(keep="first")

# %%
df.shape
# Out:
# (224179, 11)

# %%
df.shape
# Out:
# (224491, 11)

# %%
df_coordinates = pd.read_csv('df_coordinates.csv')

# %%
df_coordinates
# Out:
#       latitude   longitude block_no           street_name postal_code  \
# 0     1.366558  103.841624      215   ANG MO KIO AVENUE 1      560215
# 1     1.366197  103.841505      216   ANG MO KIO AVENUE 1      560216
# 2     1.369197  103.841667      211   ANG MO KIO AVENUE 3      560211
# 3     1.368446  103.844516      202   ANG MO KIO AVENUE 3      560202
# 4     1.366824  103.836491      235   ANG MO KIO AVENUE 3      560235
# ...        ...         ...      ...                   ...         ...
# 9826  1.323314  103.889610      83A          CIRCUIT ROAD      371083
# 9827  1.445029  103.829460     118B     CANBERRA CRESCENT      752118
# 9828  1.391577  103.870445     455A  SENGKANG WEST AVENUE      791455
# 9829  1.444637  103.829635     118A     CANBERRA CRESCENT      751118
# 9830  1.444796  103.830160     117B     CANBERRA CRESCENT      752117
#
#                      address      cbd_dist  min_dist_mrt
# 0       309 ANG MO KIO AVE 1   9301.987544    958.567424
# ...

# %%
df["address"] = df["block"] + " " + df["street_name"]
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            60.0        Improved                 1986      255000.0
# 1            68.0  New Generation                 1981      275000.0
# 2            69.0  New Generation                 1980      285000.0
# 3            68.0  New Generation                 1979      290000.0
# 4            68.0  New Generation                 1980      290000.0
#
#   remaining_lease                address
# 0              70   174 ANG MO KIO AVE 4
# ...

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# address                 object
# dtype: object

# %%
df['lease_commence_date'] = df['lease_commence_date'].astype('int64')

# %%
df_new = df_coordinates.merge(df, on="address", how='outer')
df_new
# Out:
#         latitude   longitude block_no    street_name_x postal_code  \
# 0       1.303671  103.864479        1       BEACH ROAD      190001
# 1       1.303671  103.864479        1       BEACH ROAD      190001
# 2       1.303671  103.864479        1       BEACH ROAD      190001
# 3       1.303671  103.864479        1       BEACH ROAD      190001
# 4       1.303671  103.864479        1       BEACH ROAD      190001
# ...          ...         ...      ...              ...         ...
# 224420  1.286814  103.828928       9B  BOON TIONG ROAD      163009
# 224421  1.286814  103.828928       9B  BOON TIONG ROAD      163009
# 224422  1.286814  103.828928       9B  BOON TIONG ROAD      163009
# 224423  1.286814  103.828928       9B  BOON TIONG ROAD      163009
# 224424  1.286814  103.828928       9B  BOON TIONG ROAD      163009
#
#                  address     cbd_dist  min_dist_mrt    month             town  \
# 0             1 BEACH RD  2715.822202    457.092359  2015-01  KALLANG/WHAMPOA
# ...

# %%
df_new.dtypes
# Out:
# latitude               float64
# longitude              float64
# block_no                object
# street_name_x           object
# postal_code             object
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name_y           object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date    float64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
df_new.isnull().sum()
# Out:
# latitude               208
# longitude              208
# block_no               226
# street_name_x          208
# postal_code            208
# address                  0
# cbd_dist               208
# min_dist_mrt           208
# month                  246
# town                   246
# flat_type              246
# block                  246
# street_name_y          246
# storey_range           246
# floor_area_sqm         246
# flat_model             246
# lease_commence_date    246
# resale_price           246
# remaining_lease        246
# dtype: int64

# %%
df_new = df_new.dropna()

# %%
df_new.isna().sum()
# Out:
# latitude               0
# longitude              0
# block_no               0
# street_name_x          0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name_y          0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
df_new['resale_price'] = df_new['resale_price'].astype('float')
df_new['floor_area_sqm'] = df_new['floor_area_sqm'].astype('float')
df_new['lease_commence_date'] = df_new['lease_commence_date'].astype('int64')
df_new['lease_remain_years'] = 99 - (2024 - df_new['lease_commence_date'])

# %%
df_new['lease_commence_date'] = df_new['lease_commence_date'].astype('int64')

# %%
df_new.shape
# Out:
# (223955, 20)

# %%
df_new.to_csv('combined.csv', index = False)
